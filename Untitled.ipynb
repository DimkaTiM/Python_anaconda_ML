# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import MySQLdb
from sqlalchemy import create_engine
import pymysql


# con = MySQLdb.connect(host="localhost", user="root", passwd="Y#NevcwPFRv_r!6f", db="test")
# cur = con.cursor()
# cur.execute("SELECT * FROM test")
# for row in cur.fetchall():
#     print(row)

db_connection = 'mysql+pymysql://root:YOURPASSWORD@localhost/test'
conn = create_engine(db_connection) 
df = pd.read_sql("SELECT * FROM test", conn)
print(df)

# %%
# %matplotlib inline
x = milk[:1]
y = milk[1:2]
plt.plot(milk)
plt.show()

# %%
x = milk[['milk']]

# %%
print(x.head())
sm.tsa.stattools.adfuller(milk['milk'])
# Out:
#    milk
# 0   589
# 1   561
# 2   640
# 3   656
# 4   727
# (-1.3038115874221248,
#  0.6274267086030337,
#  13,
#  154,
#  {'1%': -3.473542528196209,
#   '5%': -2.880497674144038,
#   '10%': -2.576878053634677},
#  1115.1730447395112)
